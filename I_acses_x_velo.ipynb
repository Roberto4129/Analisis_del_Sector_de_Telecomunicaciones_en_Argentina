# %%
import pandas as pd

# %%
df = pd.read_csv("data_original\Internet_Accesos-por-velocidad.csv")
df
# Out:
#       Año  Trimestre            Provincia  HASTA 512 kbps  \
# 0    2022          3         Buenos Aires          29.985
# 1    2022          3      Capital Federal         517.000
# 2    2022          3            Catamarca          71.000
# 3    2022          3                Chaco         461.000
# 4    2022          3               Chubut         109.000
# ..    ...        ...                  ...             ...
# 835  2014          1           Santa Cruz         161.000
# 836  2014          1             Santa Fe           8.456
# 837  2014          1  Santiago Del Estero           1.234
# 838  2014          1     Tierra Del Fuego          12.000
# 839  2014          1              Tucumán           6.000
#
#      + 512 Kbps - 1 Mbps + 1 Mbps - 6 Mbps  + 6 Mbps - 10 Mbps  \
# 0                 27.709           290.315             297.915
# 1                  5.742            34.371              67.829
# 2                384.000             3.107               5.389
# ...
